# %%
# import all necessary modules


# numerics, file IO, etc ...
import numpy as np
import pandas as pd
import sys,math
import os,glob
import statsmodels.api as sm


# data object
from imp import reload
import sistercellclass as scc; reload(scc)


# plotting
import matplotlib.pyplot as plt
# %matplotlib notebook
plt.rcParams['figure.figsize'] = [8, 6]
# Out:
# /usr/lib64/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# define directory for datafiles and generate data object

datadir   = '/home/lukas/projects/sistercells/experiments/SISTERS-NONSISTERS/SISTERS/'
datafiles = glob.glob(datadir + '*.xls') # get list of all files that match pattern = all Excel files in 'datadir'

data      = scc.SisterCellData(infiles = datafiles)

# %%
# basic usage of data object:
# iterate over object itself, get all trajectories back one after another
for dataID,filename,rawdata in data:
    # dataID    ... index of datafile
    # filename  ... name of file where data comes from
    # rawdata   ... pandas dataframe with all columns directly read from Excel files

    # discretize trajectories by cell division events
    cdivA,cdivB = data.CellDivisionTrajectory(dataID)

    # print(rawdata)
    
    plt.plot(rawdata['timeA'],rawdata['lengthA'])
    plt.plot(rawdata['timeB'],rawdata['lengthB'])
